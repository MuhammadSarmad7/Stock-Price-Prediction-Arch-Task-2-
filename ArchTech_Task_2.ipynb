# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv('Tasla_Stock_Updated_V2.csv')
df
# Out:
#       Unnamed: 0        Date        Open        High         Low       Close  \
# 0              0  2015-01-02   14.858000   14.883333   14.217333   14.620667
# 1              1  2015-01-05   14.303333   14.433333   13.810667   14.006000
# 2              2  2015-01-06   14.004000   14.280000   13.614000   14.085333
# 3              3  2015-01-07   14.223333   14.318667   13.985333   14.063333
# 4              4  2015-01-08   14.187333   14.253333   14.000667   14.041333
# ...          ...         ...         ...         ...         ...         ...
# 2269        2269  2024-01-09  238.110001  238.960007  232.039993  234.960007
# 2270        2270  2024-01-10  235.100006  235.500000  231.289993  233.940002
# 2271        2271  2024-01-11  230.570007  230.929993  225.369995  227.220001
# 2272        2272  2024-01-12  220.080002  225.339996  217.149994  218.889999
# 2273        2273  2024-01-16  215.100006  223.490005  212.180099  219.910004
#
#          Volume
# 0      71466000
# 1      80527500
# 2      93928500
# 3      44526000
# 4      51637500
# ...         ...
# 2269   96705700
# 2270   91628500
# 2271  105873600
# 2272  122889000
# 2273  115064708
#
# [2274 rows x 7 columns]

# %%
df.drop(['Unnamed: 0', 'Date'],axis= 1,inplace=True)
df
# Out:
#             Open        High         Low       Close     Volume
# 0      14.858000   14.883333   14.217333   14.620667   71466000
# 1      14.303333   14.433333   13.810667   14.006000   80527500
# 2      14.004000   14.280000   13.614000   14.085333   93928500
# 3      14.223333   14.318667   13.985333   14.063333   44526000
# 4      14.187333   14.253333   14.000667   14.041333   51637500
# ...          ...         ...         ...         ...        ...
# 2269  238.110001  238.960007  232.039993  234.960007   96705700
# 2270  235.100006  235.500000  231.289993  233.940002   91628500
# 2271  230.570007  230.929993  225.369995  227.220001  105873600
# 2272  220.080002  225.339996  217.149994  218.889999  122889000
# 2273  215.100006  223.490005  212.180099  219.910004  115064708
#
# [2274 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
x = df[['Open','High','Low','Volume']]
y = df['Close']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = model.predict(x_test)

# %%
mse= mean_squared_error(y_test,pred)
r2 = r2_score(y_test,pred)
print(f"Mean Squared Error : {mse}")
print(f"R2 Score : {r2}")
# Out:
# Mean Squared Error : 4.299214001111169
# R2 Score : 0.9996289001986913

# %%
pd.DataFrame({"Actual": y_test, "Predicted":pred,"Difference":y_test-pred})
# Out:
#           Actual   Predicted  Difference
# 2063  180.449997  178.269697    2.180300
# 1321   30.298000   31.064573   -0.766572
# 859    19.454666   19.288845    0.165821
# 408    14.907333   14.991090   -0.083756
# 629    23.507999   23.742106   -0.234107
# ...          ...         ...         ...
# 203    14.114667   14.208535   -0.093868
# 1879  237.036667  241.009684   -3.973017
# 719    20.292667   20.202056    0.090611
# 1134   15.356000   15.323341    0.032659
# 618    24.760000   24.765578   -0.005578
#
# [455 rows x 3 columns]
